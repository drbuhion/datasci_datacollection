# %% [markdown]
# # Getting data directly from a website
#
# By: Deborah Rose P. Buhion DATASCI S12
#
# This notebook is based from [WebScraping.ipynb](https://github.com/brianehenyo/datapre-notebooks/blob/main/notebooks/02%20-%20Web%20Scraping.ipynb)
#
# Data is from [Bulbapedia's National Pokedex](https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number)
#
# Note: This notebook is a template to extract data from one generation of Pokemon.

# %% [markdown]
# ### Import `json` library

# %%
import json

# %% [markdown]
# ### Import `requests` library

# %%
import requests

URL="https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number"

# %% [markdown]
# ### Load the page

# %%
page=requests.get(URL)

# %% [markdown]
# ### Parse HTML data

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# ### Find all tables that contain Pokemon details

# %%
# Get main content <div>
poke_content=soup.find(id='mw-content-text')

# Get all <table> elements
poke_tables=poke_content.find_all('table')

# %% [markdown]
# ### Get list of **X** Generation Pokemons

# %%
genX_list=poke_tables[8]

# %%
info_start=3

# %% [markdown]
# ### Get all Gen **X** Pokemons

# %%
for i in range(info_start, len(genX_list.contents), 2):
    poke_info=genX_list.contents[i]
    kdex=poke_info.contents[1].text.strip()
    ndex=poke_info.contents[3].text.strip()
    name=poke_info.contents[7].text.strip()
    type1=poke_info.contents[9].text.strip()
    
    href=str(poke_info.contents[7])
    start = href.find('href="') + len('href="')
    end = href.find('" ')
    substring = href[start:end]
    link_start="https://bulbapedia.bulbagarden.net"
    link=link_start+substring
    
    if len(poke_info.contents) > 10:
        type2=poke_info.contents[11].text.strip()
        print(f'Pokemon {ndex} {name} is a {type1} & {type2} Pokemon. \nLearn more here: {link}')
    else:
        print(f'Pokemon {ndex} {name} is a {type1} Pokemon. \nLearn more here: {link}')
# Out:
# Pokemon #810 Grookey is a Grass Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Grookey_(Pok%C3%A9mon)
# Pokemon #811 Thwackey is a Grass Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Thwackey_(Pok%C3%A9mon)
# Pokemon #812 Rillaboom is a Grass Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Rillaboom_(Pok%C3%A9mon)
# Pokemon #813 Scorbunny is a Fire Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Scorbunny_(Pok%C3%A9mon)
# Pokemon #814 Raboot is a Fire Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Raboot_(Pok%C3%A9mon)
# Pokemon #815 Cinderace is a Fire Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Cinderace_(Pok%C3%A9mon)
# Pokemon #816 Sobble is a Water Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Sobble_(Pok%C3%A9mon)
# Pokemon #817 Drizzile is a Water Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Drizzile_(Pok%C3%A9mon)
# Pokemon #818 Inteleon is a Water Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Inteleon_(Pok%C3%A9mon)
# Pokemon #819 Skwovet is a Normal Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Skwovet_(Pok%C3%A9mon)
# Pokemon #820 Greedent is a Normal Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Greedent_(Pok%C3%A9mon)
# Pokemon #821 Rookidee is a Flying Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Rookidee_(Pok%C3%A9mon)
# Pokemon #822 Corvisquire is a Flying Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Corvisquire_(Pok%C3%A9mon)
# Pokemon #823 Corviknight is a Flying & Steel Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/
pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Zacian_(Pok%C3%A9mon)
# Pokemon #889 Zamazenta is a Fighting Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Zamazenta_(Pok%C3%A9mon)
# Pokemon #889 Zamazenta is a Fighting & Steel Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Zamazenta_(Pok%C3%A9mon)
# Pokemon #890 Eternatus is a Poison & Dragon Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Eternatus_(Pok%C3%A9mon)
# Pokemon #891 Kubfu is a Fighting Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Kubfu_(Pok%C3%A9mon)
# Pokemon #892 Urshifu is a Fighting & Dark Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Urshifu_(Pok%C3%A9mon)
# Pokemon #892 Urshifu is a Fighting & Water Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Urshifu_(Pok%C3%A9mon)
# Pokemon #893 Zarude is a Dark & Grass Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Zarude_(Pok%C3%A9mon)
# Pokemon #894 Regieleki is a Electric Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Regieleki_(Pok%C3%A9mon)
# Pokemon #895 Regidrago is a Dragon Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Regidrago_(Pok%C3%A9mon)
# Pokemon #896 Glastrier is a Ice Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Glastrier_(Pok%C3%A9mon)
# Pokemon #897 Spectrier is a Ghost Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Spectrier_(Pok%C3%A9mon)
# Pokemon #898 Calyrex is a Psychic & Grass Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)
# Pokemon #898 Calyrex is a Psychic & Ice Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)
# Pokemon #898 Calyrex is a Psychic & Ghost Pokemon.
# Learn more here: https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)

# %% [markdown]
# ### Save them in a JSON

# %%
genX_json = []

for i in range(info_start, len(genX_list.contents), 2):
    poke_info=genX_list.contents[i]
    
    href=str(poke_info.contents[7])
    start = href.find('href="') + len('href="')
    end = href.find('" ')
    substring = href[start:end]
    link_start="https://bulbapedia.bulbagarden.net"
    link=link_start+substring
    
    kdex=poke_info.contents[1].text.strip()
    ndex=poke_info.contents[3].text.strip()
    name=poke_info.contents[7].text.strip()
    type1=poke_info.contents[9].text.strip()
    if len(poke_info.contents) > 10:
        type2=poke_info.contents[11].text.strip()
        genX_json.append({
            "kdex": kdex,
            "ndex": ndex,
            "name": name,
            "type1": type1,
            "type2": type2,
            "link": link
        })
    else:
        genX_json.append({
            "kdex": kdex,
            "ndex": ndex,
            "name": name,
            "type1": type1,
            "link": link
        })
        
genX_json
# Out:
# [{'kdex': '#001',
#   'ndex': '#810',
#   'name': 'Grookey',
#   'type1': 'Grass',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Grookey_(Pok%C3%A9mon)'},
#  {'kdex': '#002',
#   'ndex': '#811',
#   'name': 'Thwackey',
#   'type1': 'Grass',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Thwackey_(Pok%C3%A9mon)'},
#  {'kdex': '#003',
#   'ndex': '#812',
#   'name': 'Rillaboom',
#   'type1': 'Grass',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Rillaboom_(Pok%C3%A9mon)'},
#  {'kdex': '#004',
#   'ndex': '#813',
#   'name': 'Scorbunny',
#   'type1': 'Fire',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Scorbunny_(Pok%C3%A9mon)'},
#  {'kdex': '#005',
#   'ndex': '#814',
#   'name': 'Raboot',
#   'type1': 'Fire',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Raboot_(Pok%C3%A9mon)'},
#  {'kdex': '#006',
#   'ndex': '#815',
#   'name': 'Cinderace',
#   'type1': 'Fire',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Cinderace_(Pok%C3%A9mon)'},
#  {'kdex': '#007',
#   'ndex': '#816',
#   'name': 'Sobble',
#   'type1': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Sobble_(Pok%C3%A9mon)'},
#  {'kdex': '#008',
#   'ndex': '#817',
#   'name': 'Drizzile',
#   'type1': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Drizzile_(Pok%C3%A9mon)'},
#  {'kdex': '#009',
#   'ndex': '#818',
#   'name': 'Inteleon',
#   'type1': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Inteleon_(Pok%C3%A9mon)'},
#  {'kdex': '#024',
#   'ndex': '#819',
#   'name': 'Skwovet',
#   'type1': 'Normal',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Skwovet_(Pok%C3%A9mon)'},
#  {'kdex': '#025',
#   'ndex': '#820',
#   'name': 'Greedent',
#   'type1': 'Normal',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Greedent_(Pok%C3%A9mon)'},
#  {'kdex': '#021',
#   'ndex': '#821',
#   'name': 'Rookidee',
#   'type1': 'Flying',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Rookidee_(Pok%C3%A9mon)'},
#  {'kdex': '#022',
#   'ndex': '#822',
#   'name': 'Corvisquire',
#   'type1': 'Flying',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Corvisquire_(Pok%C3%A9mon)'},
#  {'kdex': '#023',
#   'ndex': '#823',
#   'name': 'Corviknight',
#   'type1': 'Flying',
#   'type2': 'Steel',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Corviknight_(Pok%C3%A9mon)'},
#  {'kdex': '#010',
#   'ndex': '#824',
#   'name': 'Blipbug',
#   'type1': 'Bug',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Blipbug_(Pok%C3%A9mon)'},
#  {'kdex': '#011',
#   'ndex': '#825',
#   'name': 'Dottler',
#   'type1': 'Bug',
#   'type2': 'Psychic',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Dottler_(Pok%C3%A9mon)'},
#  {'kdex': '#012',
#   'ndex': '#826',
#   'name': 'Orbeetle',
#   'type1': 'Bug',
#   'type2': 'Psychic',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Orbeetle_(Pok%C3%A9mon)'},
#  {'kdex': '#029',
#   'ndex': '#827',
#   'name': 'Nickit',
#   'type1': 'Dark',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Nickit_(Pok%C3%A9mon)'},
#  {'kdex': '#030',
#   'ndex': '#828',
#   'name': 'Thievul',
#   'type1': 'Dark',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Thievul_(Pok%C3%A9mon)'},
#  {'kdex': '#126',
#   'ndex': '#829',
#   'name': 'Gossifleur',
#   'type1': 'Grass',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Gossifleur_(Pok%C3%A9mon)'},
#  {'kdex': '#127',
#   'ndex': '#830',
#   'name': 'Eldegoss',
#   'type1': 'Grass',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Eldegoss_(Pok%C3%A9mon)'},
#  {'kdex': '#034',
#   'ndex': '#831',
#   'name': 'Wooloo',
#   'type1': 'Normal',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Wooloo_(Pok%C3%A9mon)'},
#  {'kdex': '#035',
#   'ndex': '#832',
#   'name': 'Dubwool',
#   'type1': 'Normal',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Dubwool_(Pok%C3%A9mon)'},
#  {'kdex': '#042',
#   'ndex': '#833',
#   'name': 'Chewtle',
#   'type1': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Chewtle_(Pok%C3%A9mon)'},
#  {'kdex': '#043',
#   'ndex': '#834',
#   'name': 'Drednaw',
#   'type1': 'Water',
#   'type2': 'Rock',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Drednaw_(Pok%C3%A9mon)'},
#  {'kdex': '#046',
#   'ndex': '#835',
#   'name': 'Yamper',
#   'type1': 'Electric',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Yamper_(Pok%C3%A9mon)'},
#  {'kdex': '#047',
#   'ndex': '#836',
#   'name': 'Boltund',
#   'type1': 'Electric',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Boltund_(Pok%C3%A9mon)'},
#  {'kdex': '#161',
#   'ndex': '#837',
#   'name': 'Rolycoly',
#   'type1': 'Rock',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Rolycoly_(Pok%C3%A9mon)'},
#  {'kdex': '#162',
#   'ndex': '#838',
#   'name': 'Carkol',
#   'type1': 'Rock',
#   'type2': 'Fire',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Carkol_(Pok%C3%A9mon)'},
#  {'kdex': '#163',
#   'ndex': '#839',
#   'name': 'Coalossal',
#   'type1': 'Rock',
#   'type2': 'Fire',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Coalossal_(Pok%C3%A9mon)'},
#  {'kdex': '#205',
#   'ndex': '#840',
#   'name': 'Applin',
#   'type1': 'Grass',
#   'type2': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Applin_(Pok%C3%A9mon)'},
#  {'kdex': '#206',
#   'ndex': '#841',
#   'name': 'Flapple',
#   'type1': 'Grass',
#   'type2': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Flapple_(Pok%C3%A9mon)'},
#  {'kdex': '#207',
#   'ndex': '#842',
#   'name': 'Appletun',
#   'type1': 'Grass',
#   'type2': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Appletun_(Pok%C3%A9mon)'},
#  {'kdex': '#312',
#   'ndex': '#843',
#   'name': 'Silicobra',
#   'type1': 'Ground',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Silicobra_(Pok%C3%A9mon)'},
#  {'kdex': '#313',
#   'ndex': '#844',
#   'name': 'Sandaconda',
#   'type1': 'Ground',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Sandaconda_(Pok%C3%A9mon)'},
#  {'kdex': '#309',
#   'ndex': '#845',
#   'name': 'Cramorant',
#   'type1': 'Flying',
#   'type2': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Cramorant_(Pok%C3%A9mon)'},
#  {'kdex': '#180',
#   'ndex': '#846',
#   'name': 'Arrokuda',
#   'type1': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Arrokuda_(Pok%C3%A9mon)'},
#  {'kdex': '#181',
#   'ndex': '#847',
#   'name': 'Barraskewda',
#   'type1': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Barraskewda_(Pok%C3%A9mon)'},
#  {'kdex': '#310',
#   'ndex': '#848',
#   'name': 'Toxel',
#   'type1': 'Electric',
#   'type2': 'Poison',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Toxel_(Pok%C3%A9mon)'},
#  {'kdex': '#311',
#   'ndex': '#849',
#   'name': 'Toxtricity',
#   'type1': 'Electric',
#   'type2': 'Poison',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Toxtricity_(Pok%C3%A9mon)'},
#  {'kdex': '#159',
#   'ndex': '#850',
#   'name': 'Sizzlipede',
#   'type1': 'Fire',
#   'type2': 'Bug',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Sizzlipede_(Pok%C3%A9mon)'},
#  {'kdex': '#160',
#   'ndex': '#851',
#   'name': 'Centiskorch',
#   'type1': 'Fire',
#   'type2': 'Bug',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Centiskorch_(Pok%C3%A9mon)'},
#  {'kdex': '#351',
#   'ndex': '#852',
#   'name': 'Clobbopus',
#   'type1': 'Fighting',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Clobbopus_(Pok%C3%A9mon)'},
#  {'kdex': '#352',
#   'ndex': '#853',
#   'name': 'Grapploct',
#   'type1': 'Fighting',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Grapploct_(Pok%C3%A9mon)'},
#  {'kdex': '#335',
#   'ndex': '#854',
#   'name': 'Sinistea',
#   'type1': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Sinistea_(Pok%C3%A9mon)'},
#  {'kdex': '#336',
#   'ndex': '#855',
#   'name': 'Polteageist',
#   'type1': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Polteageist_(Pok%C3%A9mon)'},
#  {'kdex': '#241',
#   'ndex': '#856',
#   'name': 'Hatenna',
#   'type1': 'Psychic',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Hatenna_(Pok%C3%A9mon)'},
#  {'kdex': '#242',
#   'ndex': '#857',
#   'name': 'Hattrem',
#   'type1': 'Psychic',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Hattrem_(Pok%C3%A9mon)'},
#  {'kdex': '#243',
#   'ndex': '#858',
#   'name': 'Hatterene',
#   'type1': 'Psychic',
#   'type2': 'Fairy',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Hatterene_(Pok%C3%A9mon)'},
#  {'kdex': '#238',
#   'ndex': '#859',
#   'name': 'Impidimp',
#   'type1': 'Dark',
#   'type2': 'Fairy',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Impidimp_(Pok%C3%A9mon)'},
#  {'kdex': '#239',
#   'ndex': '#860',
#   'name': 'Morgrem',
#   'type1': 'Dark',
#   'type2': 'Fairy',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Morgrem_(Pok%C3%A9mon)'},
#  {'kdex': '#240',
#   'ndex': '#861',
#   'name': 'Grimmsnarl',
#   'type1': 'Dark',
#   'type2': 'Fairy',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Grimmsnarl_(Pok%C3%A9mon)'},
#  {'kdex': '#033',
#   'ndex': '#862',
#   'name': 'Obstagoon',
#   'type1': 'Dark',
#   'type2': 'Normal',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Obstagoon_(Pok%C3%A9mon)'},
#  {'kdex': '#183',
#   'ndex': '#863',
#   'name': 'Perrserker',
#   'type1': 'Steel',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Perrserker_(Pok%C3%A9mon)'},
#  {'kdex': '#237',
#   'ndex': '#864',
#   'name': 'Cursola',
#   'type1': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Cursola_(Pok%C3%A9mon)'},
#  {'kdex': '#219',
#   'ndex': '#865',
#   'name': "Sirfetch'd",
#   'type1': 'Fighting',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Sirfetch%27d_(Pok%C3%A9mon)'},
#  {'kdex': '#366',
#   'ndex': '#866',
#   'name': 'Mr. Rime',
#   'type1': 'Ice',
#   'type2': 'Psychic',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Mr._Rime_(Pok%C3%A9mon)'},
#  {'kdex': '#328',
#   'ndex': '#867',
#   'name': 'Runerigus',
#   'type1': 'Ground',
#   'type2': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Runerigus_(Pok%C3%A9mon)'},
#  {'kdex': '#185',
#   'ndex': '#868',
#   'name': 'Milcery',
#   'type1': 'Fairy',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Milcery_(Pok%C3%A9mon)'},
#  {'kdex': '#186',
#   'ndex': '#869',
#   'name': 'Alcremie',
#   'type1': 'Fairy',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Alcremie_(Pok%C3%A9mon)'},
#  {'kdex': '#345',
#   'ndex': '#870',
#   'name': 'Falinks',
#   'type1': 'Fighting',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Falinks_(Pok%C3%A9mon)'},
#  {'kdex': '#353',
#   'ndex': '#871',
#   'name': 'Pincurchin',
#   'type1': 'Electric',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Pincurchin_(Pok%C3%A9mon)'},
#  {'kdex': '#349',
#   'ndex': '#872',
#   'name': 'Snom',
#   'type1': 'Ice',
#   'type2': 'Bug',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Snom_(Pok%C3%A9mon)'},
#  {'kdex': '#350',
#   'ndex': '#873',
#   'name': 'Frosmoth',
#   'type1': 'Ice',
#   'type2': 'Bug',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Frosmoth_(Pok%C3%A9mon)'},
#  {'kdex': '#369',
#   'ndex': '#874',
#   'name': 'Stonjourner',
#   'type1': 'Rock',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Stonjourner_(Pok%C3%A9mon)'},
#  {'kdex': '#370',
#   'ndex': '#875',
#   'name': 'Eiscue',
#   'type1': 'Ice',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Eiscue_(Pok%C3%A9mon)'},
#  {'kdex': '#337',
#   'ndex': '#876',
#   'name': 'Indeedee',
#   'type1': 'Psychic',
#   'type2': 'Normal',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Indeedee_(Pok%C3%A9mon)'},
#  {'kdex': '#344',
#   'ndex': '#877',
#   'name': 'Morpeko',
#   'type1': 'Electric',
#   'type2': 'Dark',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Morpeko_(Pok%C3%A9mon)'},
#  {'kdex': '#302',
#   'ndex': '#878',
#   'name': 'Cufant',
#   'type1': 'Steel',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Cufant_(Pok%C3%A9mon)'},
#  {'kdex': '#303',
#   'ndex': '#879',
#   'name': 'Copperajah',
#   'type1': 'Steel',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Copperajah_(Pok%C3%A9mon)'},
#  {'kdex': '#374',
#   'ndex': '#880',
#   'name': 'Dracozolt',
#   'type1': 'Electric',
#   'type2': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Dracozolt_(Pok%C3%A9mon)'},
#  {'kdex': '#375',
#   'ndex': '#881',
#   'name': 'Arctozolt',
#   'type1': 'Electric',
#   'type2': 'Ice',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Arctozolt_(Pok%C3%A9mon)'},
#  {'kdex': '#376',
#   'ndex': '#882',
#   'name': 'Dracovish',
#   'type1': 'Water',
#   'type2': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Dracovish_(Pok%C3%A9mon)'},
#  {'kdex': '#377',
#   'ndex': '#883',
#   'name': 'Arctovish',
#   'type1': 'Water',
#   'type2': 'Ice',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Arctovish_(Pok%C3%A9mon)'},
#  {'kdex': '#371',
#   'ndex': '#884',
#   'name': 'Duraludon',
#   'type1': 'Steel',
#   'type2': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Duraludon_(Pok%C3%A9mon)'},
#  {'kdex': '#395',
#   'ndex': '#885',
#   'name': 'Dreepy',
#   'type1': 'Dragon',
#   'type2': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Dreepy_(Pok%C3%A9mon)'},
#  {'kdex': '#396',
#   'ndex': '#886',
#   'name': 'Drakloak',
#   'type1': 'Dragon',
#   'type2': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Drakloak_(Pok%C3%A9mon)'},
#  {'kdex': '#397',
#   'ndex': '#887',
#   'name': 'Dragapult',
#   'type1': 'Dragon',
#   'type2': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Dragapult_(Pok%C3%A9mon)'},
#  {'kdex': '#398',
#   'ndex': '#888',
#   'name': 'Zacian',
#   'type1': 'Fairy',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Zacian_(Pok%C3%A9mon)'},
#  {'kdex': '#398',
#   'ndex': '#888',
#   'name': 'Zacian',
#   'type1': 'Fairy',
#   'type2': 'Steel',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Zacian_(Pok%C3%A9mon)'},
#  {'kdex': '#399',
#   'ndex': '#889',
#   'name': 'Zamazenta',
#   'type1': 'Fighting',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Zamazenta_(Pok%C3%A9mon)'},
#  {'kdex': '#399',
#   'ndex': '#889',
#   'name': 'Zamazenta',
#   'type1': 'Fighting',
#   'type2': 'Steel',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Zamazenta_(Pok%C3%A9mon)'},
#  {'kdex': '#400',
#   'ndex': '#890',
#   'name': 'Eternatus',
#   'type1': 'Poison',
#   'type2': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Eternatus_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#891',
#   'name': 'Kubfu',
#   'type1': 'Fighting',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Kubfu_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#892',
#   'name': 'Urshifu',
#   'type1': 'Fighting',
#   'type2': 'Dark',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Urshifu_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#892',
#   'name': 'Urshifu',
#   'type1': 'Fighting',
#   'type2': 'Water',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Urshifu_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#893',
#   'name': 'Zarude',
#   'type1': 'Dark',
#   'type2': 'Grass',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Zarude_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#894',
#   'name': 'Regieleki',
#   'type1': 'Electric',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Regieleki_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#895',
#   'name': 'Regidrago',
#   'type1': 'Dragon',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Regidrago_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#896',
#   'name': 'Glastrier',
#   'type1': 'Ice',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Glastrier_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#897',
#   'name': 'Spectrier',
#   'type1': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Spectrier_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#898',
#   'name': 'Calyrex',
#   'type1': 'Psychic',
#   'type2': 'Grass',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#898',
#   'name': 'Calyrex',
#   'type1': 'Psychic',
#   'type2': 'Ice',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)'},
#  {'kdex': '#---',
#   'ndex': '#898',
#   'name': 'Calyrex',
#   'type1': 'Psychic',
#   'type2': 'Ghost',
#   'link': 'https://bulbapedia.bulbagarden.net/wiki/Calyrex_(Pok%C3%A9mon)'}]

# %% [markdown]
# ### Write to a JSON file
#
# Change number according to what generation

# %%
filename='Pokemon Generation ' + '8'

# %%
with open(filename, 'w') as f:
    json.dump(genX_json, f)
